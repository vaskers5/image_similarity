# %%
# import gdown

# # a file
# id = "1BhkXODSOqM1FGsLUwM6ynb99psKH0BKo"
# output = "1m_tokens.tar.gz"
# gdown.download(id=id, output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BhkXODSOqM1FGsLUwM6ynb99psKH0BKo
# To: /home/neiromed/projects/image_similarity/data/1m_tokens.tar.gz
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 3.82G/3.82G [03:31<00:00, 18.1MB/s]
# '1m_tokens.tar.gz'

# %%
import pandas as pd

df = pd.read_csv('full_data/full_data.csv')

# %%
df['local_path'].to_list()
# Out:
# ['/home/neiromed/projects/image_similarity/data/full_data/img_data/26198507.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26196094.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26196655.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26194528.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26194928.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26194090.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26190654.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26195338.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26193663.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26192705.png',
#  '/home/neiromed/projects/image_similarity/data/full_data/img_data/26198662.png',
# ...

# %%
#!tar -xvf 1m_tokens.tar.gz
# Out:
# 1m_tokens.csv

# %%
import pandas as pd
import pandas as pd
import requests

from tqdm import tqdm
tqdm.pandas()

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
df = pd.read_csv('1m_tokens.csv')

# %%
df
# Out:
#               id                                         externalId  \
# 0       26198507  2267467665518878757913461207941762113461021996...
# 1       26196094  8229443055029609268200373483723609407551982119...
# 2       26196655  8229443055029609268200373483723609407551982119...
# 3       26194528  8229443055029609268200373483723609407551982119...
# 4       26194928  8229443055029609268200373483723609407551982119...
# ...          ...                                                ...
# 992413  27138397  1021624614641528452261144525295482454817753153...
# 992414  27133009  1021624614641528452261144525295482454817753153...
# 992415  27134425  1021624614641528452261144525295482454817753153...
# 992416  27135808  1021624614641528452261144525295482454817753153...
# 992417  27131594  1021624614641528452261144525295482454817753153...
#
#                       tokenName  collectionId           collectionName  \
# 0         Carnivarous Plant #36       1411901  CarnivarousPlantClub V3
# ...

# %%
df = df.dropna(subset=['id', 'url']).drop_duplicates(subset=['id', 'url'], keep='first', ignore_index=True)

# %%
df.iloc[:40].to_csv('test.csv', index=False)

# %%
test_df = df.iloc[:500]

# %%
test_df.to_csv('test.csv', index=False)

# %%
os.mkdir('test_dir')

# %%
os.path.exists('rofl_dir')
# Out:
# False

# %%
import os

IMAGE_FOLDER = os.path.abspath('full_img_data')

# %%
import requests
from typing import Optional
from pathlib import Path


IMAGE_FOLDER = Path('full_img_data')

def load_data(img_id: str, url: str) -> Optional[str]:
    if url.startswith('ipfs://'):
        url = url.replace('ipfs://', 'https://ipfs.io/ipfs/')
    print('da')
        data = requests.get(url, timeout=10).content
    except:
        return None
    local_path = os.path.join(IMAGE_FOLDER, f'{img_id}.png')
    with open(local_path, 'wb') as f:
        f.write(data)
    return local_path

# %%
test_df.parallel_apply(lambda x: load_data(x.id, x.url), axis=1)

# %%
df.drop(['Unnamed: 0'], axis=1).dropna(subset=['id', 'url'])
# Out:
#               id                                         externalId  \
# 0       26198507  2267467665518878757913461207941762113461021996...
# 1       26196094  8229443055029609268200373483723609407551982119...
# 2       26196655  8229443055029609268200373483723609407551982119...
# 3       26194528  8229443055029609268200373483723609407551982119...
# 4       26194928  8229443055029609268200373483723609407551982119...
# ...          ...                                                ...
# 548300  26691802  8501720184752691225029463441242565407605733235...
# 548301  26692644  8501720184752691225029463441242565407605733235...
# 548302  26694845  8271869502200047581865074912889966895952887427...
# 548303  26692149  8271869502200047581865074912889966895952887427...
# 548304  26692795  8271869502200047581865074912889966895952887427...
#
#                            tokenName  collectionId  \
# 0              Carnivarous Plant #36       1411901
# ...
